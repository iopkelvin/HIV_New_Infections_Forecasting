# %%
import Dataset as d
import Scrapped_datasets as v
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression, Lasso, Ridge
import seaborn as sns
import importlib
import matplotlib.pyplot as plt
import statsmodels.api as sm
import xgboost as xgb
from sklearn.preprocessing import StandardScaler

# %%
hiv_data = d.hiv_data
issue = 'new_infections'
year = 'year'
group = 'continent'
population = 'country'
years_to_predict = 6
since = 2000
prediction = 'prediction'
model = Ridge()
hiv_data.shape
# Out:
# (6468, 12)

# %%
#country_data[~country_data.country.isin(list(data.country.unique()))].country.index
importlib.reload(d)
importlib.reload(v)
# Out:
# <module 'Scrapped_datasets' from '/Users/kelvin/sf19_ds16/Projects/Causes of Death/Scrapped_datasets.py'>

# %%
#Merge HIV data and Country INFO
data, cont, income = d.merge_data_pop(hiv_data)
print(data.shape)
print(cont.shape)
print(income.shape)
# Out:
# (5544, 13)
# (700, 12)
# (196, 12)

# %%
#Add prediction label and separate into train, train label, and test
x,y,e = d.train_label_test(data, issue, years_to_predict)
print(x.shape)
print(y.shape)
print(e.shape)
# Out:
# (4356, 245)
# (4356,)
# (1188, 245)

# %%
#Regression for each group
final_data = d.predict_regression(x, y, e, model, since, years, "country")

# %%
final_data[final_data["country"] == "Brazil"]
# Out:
#     country      continent    prediction  year      death  new_infections  \
# 766  Brazil  south_america  49058.482000  2000  14510.717       44899.786
# 767  Brazil  south_america  52325.579000  2001  14620.675       45865.627
# 768  Brazil  south_america  56155.509000  2002  14539.642       46086.015
# 769  Brazil  south_america  59905.418000  2003  14942.367       46006.636
# 770  Brazil  south_america  62884.891000  2004  14593.659       46118.080
# 771  Brazil  south_america  65380.562000  2005  14568.090       46940.845
# 772  Brazil  south_america  68102.866000  2006  14410.314       49058.482
# 773  Brazil  south_america  71007.511000  2007  14553.431       52325.579
# 774  Brazil  south_america  74041.613000  2008  15042.930       56155.509
# 775  Brazil  south_america  77165.685000  2009  15065.926       59905.418
# 776  Brazil  south_america  80289.276000  2010  15292.554       62884.891
# 777  Brazil  south_america  83332.823000  2011  15226.875       65380.562
# 778  Brazil  south_america  79694.284388  2012  15123.228       68102.866
# 779  Brazil  south_america  81956.075259  2013  15488.001       71007.511
# 780  Brazil  south_america  84803.430885  2014  15432.970       74041.613
# 781  Brazil  south_america  86285.415470  2015  15408.257       77165.685
# 782  Brazil  south_america  87249.604401  2016  15242.898       80289.276
# 783  Brazil  south_america  88122.609927  2017  15405.916       83332.823
#
#      living_with_hiv  hiv_age_15_49  hiv_under_5(per_100,000)  \
# 766       316598.856          0.298                     8.476
# 767       339398.425          0.312                     7.616
# 768       367478.383          0.329                     6.828
# 769       398506.613          0.347                     6.505
# 770       429903.516          0.364                     5.849
# 771       458881.670          0.380                     5.589
# 772       487003.809          0.394                     5.237
# 773       517485.824          0.409                     4.611
# 774       549664.974          0.424                     4.389
# 775       582796.309          0.440                     3.618
# 776       616099.051          0.455                     3.702
# 777       651149.165          0.471                     3.290
# 778       689977.543          0.488                     3.072
# 779       732311.800          0.508                     2.910
# 780       777811.439          0.529                     2.601
# 781       826183.573          0.551                     2.566
# 782       876848.899          0.573                     2.599
# 783       929164.565          0.597                     2.525
#
#      hiv_all_ages(per_100,000)  hiv_70+(per_100,000)  \
# 766                      8.337                 1.316
# 767                      8.282                 1.333
# 768                      8.123                 1.373
# 769                      8.235                 1.488
# 770                      7.937                 1.573
# 771                      7.820                 1.590
# 772                      7.637                 1.589
# 773                      7.617                 1.736
# 774                      7.779                 1.874
# 775                      7.700                 1.737
# 776                      7.727                 2.013
# 777                      7.609                 2.116
# 778                      7.477                 2.145
# 779                      7.579                 2.258
# 780                      7.479                 2.381
# 781                      7.398                 2.512
# 782                      7.255                 2.455
# 783                      7.273                 2.462
#
#      hiv_age_5_14(per_100,000)  hiv_age_15_49(per_100,000)  \
# 766                      0.754                      11.643
# 767                      0.826                      11.444
# 768                      0.891                      11.286
# 769                      0.946                      11.296
# 770                      0.844                      10.894
# 771                      0.844                      10.495
# 772                      0.770                      10.214
# 773                      0.780                      10.254
# 774                      0.811                      10.370
# 775                      0.672                      10.261
# 776                      0.676                      10.158
# 777                      0.668                       9.997
# 778                      0.605                       9.695
# 779                      0.589                       9.749
# 780                      0.511                       9.455
# 781                      0.541                       9.243
# 782                      0.560                       8.933
# 783                      0.530                       9.049
#
#      hiv_age_50_69(per_100,000)
# 766                       8.007
# 767                       8.768
# 768                       8.446
# 769                       9.197
# 770                       8.989
# 771                       9.744
# 772                       9.683
# 773                       9.543
# 774                      10.104
# 775                      10.437
# 776                      10.668
# 777                      10.480
# 778                      10.673
# 779                      10.996
# 780                      11.360
# 781                      11.338
# 782                      11.319
# 783                      11.003

# %%
d.plot_time_group(final_data, prediction, years_to_predict, group, 'country')

# %%
model = sm.OLS(y_train, x_train)
results = model.fit()
#results.summary()

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
lr.score(x_test, y_test)

# %%
lrl = Lasso(alpha=0.1)
lrl.fit(x_train, y_train)
lrl.score(x_test, y_test)

# %%
lrr = Ridge(alpha=1.0)
lrr.fit(x_train, y_train)
lrr.score(x_test, y_test)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20)

# %%
from statsmodels.genmod.families import Poisson
model1 = sm.GLM(y_train, x_train, family = Poisson()).fit()

# %%
model1.summary()

# %%
model = xgb.XGBRegressor(objective="reg:squarederror")
model.fit(x_train, y_train)
predict = model.predict(x_test)
score = model.score(x_test, y_test)
print("CV score: ", np.mean(cross_val_score(model, x_test, y_test, cv=10)))
print("XGB Classifier: %.2f%%" % (score * 100.0))
